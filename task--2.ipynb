# %%
import pandas as pd

# %%
df = pd.read_csv("Data_Dealers.csv")
# Out:
# /tmp/ipykernel_37898/2947454965.py:1: DtypeWarning: Columns (11,12,15,17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Data_Dealers.csv")

# %% [markdown]
# df.info()

# %%
pd.to_numeric(df['Amount'], errors='coerce')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df['Amount'] = df['Amount'].fillna(0)

# %%
df.describe()
# Out:
#                         Created_Date         Amount       Quantity  \
# count                         298430  298430.000000  298430.000000
# mean   2025-05-18 11:25:22.439432704      12.404439       2.775334
# min              2025-05-01 00:00:00       0.000000       1.000000
# 25%              2025-05-10 00:00:00       0.000000       1.000000
# 50%              2025-05-20 00:00:00       1.000000       1.000000
# 75%              2025-05-27 00:00:00       4.000000       1.000000
# max              2025-05-31 00:00:00   50000.000000   50000.000000
# std                              NaN     380.682105     204.849290
#
#        Product_encoded  Is_High_Value      HighValue
# count    298430.000000  298430.000000  298430.000000
# mean         47.227172       0.112700       0.000881
# min           0.000000       0.000000       0.000000
# 25%          43.000000       0.000000       0.000000
# 50%          51.000000       0.000000       0.000000
# 75%          59.000000       0.000000       0.000000
# max          60.000000       1.000000       1.000000
# std          14.107371       0.316226       0.029673

# %% [markdown]
# ### 1)  Data Wrangling
# #### How would you combine the separate Created Date and Created Time columns into a single, usable datetime object in Python/Pandas?

# %%
df['datetime'] = df['Created_Date'] + ' ' + df['Time']
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
print(df[['Created_Date', 'Time', 'datetime']].head())
# Out:
#   Created_Date      Time             datetime
# 0   31/05/2025  23:59:49  31/05/2025 23:59:49
# 1   31/05/2025  23:59:37  31/05/2025 23:59:37
# 2   31/05/2025  23:59:37  31/05/2025 23:59:37
# 3   31/05/2025  23:59:37  31/05/2025 23:59:37
# 4   31/05/2025  23:59:37  31/05/2025 23:59:37

# %% [markdown]
# ### 2)Aggregation
# #### Write a Pandas command or pseudo-code to calculate the total sales Amount for each unique Region.

# %%
#Q:2
total_sales_per_region = df.groupby('Region')['Amount'].sum().reset_index()

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

total_sales_per_region.to_string(index=False)

print(total_sales_per_region)
# Out:
#                            Region      Amount
# 0                               0     3648.23
# 1                    Ad Dahkiliya       13.00
# 2                   Ad Dakhiliyah    22957.75
# 3                     Ad Dakhlyia       20.00
# 4                     Ad Dhahirah    30230.75
# 5                     Ad Dhakliya       45.00
# 6                     Ad Dhaklyia      688.00
# 7                            Adam       24.00
# 8                       Al Amarat       16.00
# 9                       Al Awabi         8.00
# 10                     Al Batinah        1.00
# 11               Al Batinah North    19264.15
# 12   Al Batinah North Governorate    75728.60
# 13               Al Batinah South     4614.00
# 14   Al Batinah South Governorate    27257.00
# 15                      Al Bidaya        3.00
# 16                     Al Buraimi     3697.50
# 17         Al Buraimi Governorate     7867.10
# 18                     Al Burami        26.00
# 19            Al Kamil Wa Al Wafi      124.00
# 20                  Al Khabourah         2.00
# 21                     Al Khabura       35.00
# 22                    Al Khaburah      494.00
# 23                   Al Khaburah        34.00
# 24                     Al Mudaibi        7.00
# 25                     Al Musanna        2.00
# 26               Al North Barinah      311.00
# 27               Al North Batinah      650.00
# 28                       Al Qabil       24.00
# 29                       Al Qurum      510.00
# 30                        Al Seeb    27410.00
# 31                       Al Seeb       178.00
# 32              Al Sharqiya South       84.00
# 33             Al Sharqiyah North        3.00
# 34             Al Sharqiyah South       41.00
# 35                      Al Suwaiq       77.00
# 36                      Al Suwayq       51.00
# 37                       Al Wusta    11164.05
# 38          Al Wusta Governorate       181.00
# 39                    Al khaborah        0.00
# 40                        Al-Duqm      127.00
# 41                    Al-Musanna        84.00
# 42                      Al-Rustaq      196.00
# 43                      Alburaimi     1133.37
# 44                     Aldhahirah       91.00
# 45                         Amarat      466.05
# 46                        Amarat       380.15
# 47                      As Suwayq      445.00
# 48                  Ash Sharqiyah       34.00
# 49            Ash Sharqiyah North    23732.35
# 50            Ash Sharqiyah South    64014.95
# 51                   Ash Sharqyia        5.00
# 52                          Bahla       81.00
# 53                          Barka     2030.31
# 54               Barka ABT Outlet     1122.96
# 55                       Barka320      763.92
# 56                      Barka_ABT      128.44
# 57              Barka_LULU_Outlet     1118.33
# 58              Barka_LULU_outlet     1182.63
# 59                  Batinah South        1.00
# 60                        Bawshar     1173.00
# 61                        Bawsher       38.00
# 62                        Buraimi     1480.21
# 63                   Daba Al biya      138.00
# 64                   Daba Al-Biya       18.00
# 65                     Dakhiliyah       18.00
# 66                        Darsait      465.00
# 67                       Darsait       147.00
# 68                 Deema W Tayeen       96.00
# 69                      Dhahirah        80.00
# 70                         Dhofar   137593.18
# 71                        Dhofar      1973.00
# 72                           Duqm      475.00
# 73                    FALAJ SOHAR        0.00
# 74                  Falaj Al Sham       76.00
# 75                 Falaj al Qabil        2.00
# 76                       Ghubrah        22.00
# 77                           Hail       90.00
# 78                          Haima       16.00
# 79                           IBRA      853.00
# 80                           IBRI     7752.60
# 81                           Ibra        5.00
# 82                          Ibra        27.00
# 83                           Ibri    12186.00
# 84                         Jalaan       94.00
# 85             Jalaan Bani Bu Ali      444.00
# 86                          Jalan     9587.10
# 87                         Jalan      5458.73
# 88              Jalan Bani Bu Ali       10.00
# 89            Jalan Bani Buhassan      296.00
# 90           Jalan bani Bu Hassan        2.00
# 91                         Khasab        6.00
# 92                        Khasab       166.00
# 93                           LIWA        8.00
# 94                           Liwa      472.00
# 95                         MUSCAT       98.00
# 96                       MUSSANNA        1.00
# 97                         Mabila     1309.00
# 98                         Mahoot      190.00
# 99                         Masqat   151695.30
# 100                        Musact     2615.75
# 101                      Musandam     4026.00
# 102                     Musandam     18443.75
# 103                        Muscat  2818164.27
# 104                       Muscat      1212.52
# 105                        Mutrah       84.00
# 106                       Muttrah      741.00
# 107                         NIZWA     1508.41
# 108                         Nizwa    10406.47
# 109              North Al Batinah     1187.00
# 110            North Al Dakhliya       140.00
# 111           North Al Dakhliya          1.00
# 112                 North Batinah       26.00
# 113               North Batinah         42.00
# 114                          OMAN        1.00
# 115               Omanphone Saham     2350.20
# 116               Omanphone Store     1736.17
# 117                        Rustaq      184.00
# 118                       Rustaq        99.00
# 119                         SOHAR       34.00
# 120             SOUTH Al Dakliya         4.00
# 121            SOUTH Al Dakliya          4.00
# 122                           SUR       52.00
# 123                       SUWAIQ         8.00
# 124                         Saham     2570.00
# 125                       Salalah     7254.60
# 126                      Salalah      4263.50
# 127                 Samad Al Shan       39.00
# 128                         Sarab       28.00
# 129                          Seeb      102.00
# 130                        Shinas      283.00
# 131                         Shoar       36.00
# 132                         Sinaw     7411.47
# 133                         Sohar    34688.03
# 134                        Sohar         0.00
# 135              South Al Batinah       96.00
# 136              South Al Dakliya        4.00
# 137             South Al Dakliya         1.00
# 138                 South Batinah       51.00
# 139                South Batinah        23.00
# 140               South Sharqiya        88.00
# 141                         Suhar     4273.34
# 142                           Sur    34524.95
# 143                        Swuaiq       14.00
# 144                         Taqah      244.00
# 145                     Thumarait       26.00
# 146                    Wadi Kabir      472.15
# 147                        YANQUL       59.00
# 148                            aa      717.96
# 149                    al hoqain        12.00
# 150                   al khaburah       74.00
# 151                       alansab       12.00
# 152                     albatinah       71.00
# 153                       alseeb        13.00
# 154                        bahlah       82.00
# 155                         barka      612.24
# 156                        bidiya        5.00
# 157                        busher    56564.70
# 158                          ibra       96.00
# 159                          ibri       32.00
# 160                      khaboura        1.00
# 161                        khoudh      406.00
# 162                       musanah        7.00
# 163                        muscat     8266.31
# 164                         nizwa     1332.02
# 165                         saham      303.00
# 166                       salalah     1287.91
# 167                        shinas      207.00
# 168                         sinaw     1628.38
# 169                         sohar     1265.00
# 170                        suwaiq       49.00

# %% [markdown]
# ### 3) Visualization
# #### What type of chart would you use to visualize the distribution of Amount (the transaction values), and why would you choose that plot?

# %% [markdown]
# ##### Histogram: because we can see whether most transactions are small, medium, or large

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


sns.histplot(df['Amount'], bins=50, log_scale=True, kde=True, color='pink', edgecolor='red')
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### *here Code to convert an entire column to text (string) so it can be properly recognized, because some values contain commas, spaces, or are stored as objects, so we force them to become strings).

# %%
import pandas as pd
import numpy as np

df['Amount'] = df['Amount'].astype(str).str.replace(',', '', regex=False)

df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

df['Amount'] = df['Amount'].fillna(0)

# %%
import pandas as pd
import numpy as np

df['ProductName'] = df['ProductName'].astype(str).str.replace(',', '', regex=False)
df['ProductName'] = pd.to_numeric(df['ProductName'], errors='coerce')
df['ProductName'] = df['ProductName'].fillna(0)


df['Quantity'] = df['Quantity'].astype(str).str.replace(',', '', regex=False)
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')
df['Quantity'] = df['Quantity'].fillna(0)

# %% [markdown]
# ### 4) Categorical Analysis
# #### How would you identify the top 5 best-selling Product Name based on the total Quantity sold?

# %%
#Q:4
top_Products_by_Quantity = df.groupby('ProductName')['Quantity'].sum().reset_index(name='Total_Quantity_Sold')
sorted_Products = top_Products_by_Quantity.sort_values(by='Total_Quantity_Sold', ascending=False)
top_5_Products = sorted_Products.head(5)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)


print(top_5_Products)
# Out:
#                        ProductName  Total_Quantity_Sold
# 47                Transfer Product             377577.0
# 43                             SIM             218776.0
# 51  Vodafone RED Advance 271217760              48397.0
# 59                          number              43253.0
# 60                         sim_fee              41632.0

# %% [markdown]
# ### 5) Feature Engineering
# #### The Product Name column is a string. If you were preparing this for a machine learning model, what is the most basic encoding technique you would apply to convert it into a numerical feature?

# %%
#Q:5
import pandas as pd
from sklearn .preprocessing import LabelEncoder

Le = LabelEncoder()
df['Product_encoded'] = le.fit_transform(df['ProductName'])
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

print(df[['ProductName', 'Product_encoded']].head())
# Out:
#                       ProductName  Product_encoded
# 0  Vodafone RED Advance 271217760               51
# 1                         sim_fee               60
# 2                             SIM               43
# 3                          number               59
# 4  Vodafone RED Advance 271217760               51

# %% [markdown]
# ### 6)Target Variable
# #### If the business goal is to predict if a transaction will be "high-value," how would you define your target variable, and would this be a classification or regression task?

# %%
df['HighValue'] = df ['Amount'].apply(lambda x: 1 if x > 1000 else 0)
print(df[['Amount', 'HighValue']].head())
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
#    Amount  HighValue
# 0     4.0          0
# 1     1.0          0
# 2     0.0          0
# 3     0.0          0
# 4     4.0          0

# %% [markdown]
# #### ***"Code to check and verify the correct column names**

# %%
print(df.columns.tolist())
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
# ['Order-Id', 'Created_Date', 'Time', 'Sender', 'Receiver', 'Reseller Path', 'Parent Reseller', 'Seller Reseller Type', 'Order-Type', 'Product', 'Amount', 'Receiver-Msisdn', 'SIM_serial', 'Balance-before', 'Balance-after', 'SellerMSISDN', 'SellerName', 'Quantity', 'PaymentMode', 'PaymentAgreement', 'TransactionNumber', 'City', 'Area', 'Region', 'ProductName', 'Product_encoded', 'Is_High_Value', 'datetime']

# %% [markdown]
# ### 7) Outlier Detection
# #### Briefly describe a simple, rule-based method you could use to identify potential outliers in the Amount column.

# %%
#Q:7
import pandas as pd
df = pd.read_csv("Data_Dealers.csv")

df['Amount'] = pd.to_numeric(df['Amount'].astype(str).str.replace(',', '').str.strip(), errors='coerce')

df_clean = df.dropna(subset=['Amount'])

Q1 = df_clean['Amount'].quantile(0.25)
Q3 = df_clean['Amount'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR


outliers = df_clean[(df_clean['Amount'] < lower_bound) | (df_clean['Amount'] > upper_bound)]
outlier_count = outliers.shape[0]
print('number of outliers:', outlier_count)
# Out:
# /tmp/ipykernel_87/3288585423.py:3: DtypeWarning: Columns (11,12,15,17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Data_Dealers.csv")
# number of outliers: 19635

# %% [markdown]
# ### 8)Comparison Analysis
# #### How would you calculate and compare the average Amount for transactions where the Payment Type is 'CASH' versus 'OFRONT'?

# %%
#Q:8
df['Amount'] = (
    df['Amount']
    .astype(str)
    .str.replace(',', '', regex=False)
    .str.replace(' ', '', regex=False)
    .str.extract(r'(\d+\.?\d*)')
)

df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

df['PaymentMode'] = df['PaymentMode'].astype(str).str.upper().str.strip()

comparison = df.groupby('PaymentMode')['Amount'].mean()

print(comparison.loc[['CASH', 'NO_PAYMENT_REQD']])
# Out:
# PaymentMode
# CASH                8.323602
# NO_PAYMENT_REQD    45.135385
# Name: Amount, dtype: float64

# %% [markdown]
# ### 9)KPI Definition
# #### Based on this dataset, propose a simple, measurable Key Performance Indicator (KPI) that the Sales team could track daily to measure operational success.

# %%
import pandas as pd
df['Created_Date'] = pd.to_datetime(df['Created_Date'])
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')
daily_sales = df.groupby('Created_Date')['Amount'].sum().reset_index(name='dailysales')
average_daily_sales = daily_sales['dailysales'].mean()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
print("daily sales per date:")
print(daily_sales)
print(f"\nAverage daily sales:{average_daily_sales:.2f}")
# Out:
# daily sales per date:
#    Created_Date  dailysales
# 0    2025-05-01    97315.24
# 1    2025-05-02    30464.64
# 2    2025-05-03    47599.56
# 3    2025-05-04   145067.01
# 4    2025-05-05    87965.10
# 5    2025-05-06   255571.10
# 6    2025-05-07    97291.72
# 7    2025-05-08    90041.59
# 8    2025-05-09    33130.35
# 9    2025-05-10   195371.09
# 10   2025-05-11    76368.77
# 11   2025-05-12   101888.62
# 12   2025-05-13   211398.74
# 13   2025-05-14   145777.98
# 14   2025-05-15    67100.84
# 15   2025-05-16    39776.19
# 16   2025-05-17    47237.20
# 17   2025-05-18    81367.67
# 18   2025-05-19   143852.50
# 19   2025-05-20    96422.26
# 20   2025-05-21    49974.11
# 21   2025-05-22    76195.06
# 22   2025-05-23    48405.61
# 23   2025-05-24    65584.33
# 24   2025-05-25   152182.05
# 25   2025-05-26   139890.86
# 26   2025-05-27   626222.74
# 27   2025-05-28   116354.66
# 28   2025-05-29   179067.38
# 29   2025-05-30    95727.12
# 30   2025-05-31    61244.72
#
# Average daily sales:119414.74

# %% [markdown]
# ### 10)Business Insight
# #### You find that a specific City has a significantly lower average Amount but a much higher average Quantity. What business hypothesis would you form based on this finding?

# %%
#Q:10
import pandas as pd
df['Amount'] = df['Amount'].astype(str).str.replace(',', '', regex=False)
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')

df = df.dropna(subset=['Amount', 'Quantity', 'City'])

City_summary = df.groupby('City').agg(
    AvgAmount=('Amount', 'mean'),
    AvgQuantity=('Quantity', 'mean')
).reset_index()
City_summary = City_summary.sort_values(by='AvgAmount')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

print(City_summary)
# Out:
#                          City   AvgAmount  AvgQuantity
# 66                Al Khaborah    0.000000     1.000000
# 385                     SAHAM    0.000000     1.000000
# 221                     FALAJ    0.000000     1.000000
# 280      Jalan bani Bu Hassan    0.222222     1.000000
# 35                 Al Batinah    0.250000     1.000000
# 423         South Al Dakliya     0.250000     1.000000
# 68              Al Khabourah     0.250000     1.000000
# 360       North Al Dakhliya      0.250000     1.000000
# 477                    alseeb    0.250000     1.000000
# 309                 Maabailah    0.250000     1.000000
# 484                    bidiya    0.250000     1.000000
# 492                  khaboura    0.250000     1.000000
# 285                    Kadara    0.250000     1.000000
# 314                   Mabelah    0.281250     1.000000
# 179            Bengali Market    0.298146     1.000000
# 180                     Bhuka    0.333333     1.000000
# 518                    suwaiq    0.395161     1.000000
# 211                     Dibba    0.400000     1.000000
# 260                    Ibri      0.538462     1.000000
# 502                   musanah    0.583333     1.000000
# 36                  Al Bidaya    0.600000     1.000000
# 519                    swuaiq    0.608696     1.000000
# 204                  Darsait     0.693396     1.000000
# 270                    Jalaan    0.696296     1.000000
# 115                  Al Wusta    0.727273     1.000000
# 13                 AL Sharqia    0.750000     1.000000
# 231                   GHUBRAH    0.750000     1.000000
# 497             mabela sanaya    0.777778     1.000000
# 103                 Al Saadah    0.888889     1.000000
# 403                    Sallah    0.904762     1.000000
# 242                      Hail    0.909091     1.000000
# 402              Salalah City    0.952172     1.000000
# 183                   Bidaya     0.975000     1.000000
# 306                  MUSSANNA    1.000000     1.000000
# 340                  Murayrat    1.000000     1.000000
# 159                Az Zawiyah    1.000000     1.000000
# 80                 Al Kwuriat    1.000000     1.000000
# 170                   Barzman    1.000000     1.000000
# 6                    AL Ansab    1.000000     1.000000
# 520                 wadi adai    1.000000     1.000000
# 186           Bidiya Al idris    1.000000     1.000000
# 426           South Sharqiya     1.000000     1.000000
# 224           Falaj Al Qabail    1.000000     1.000000
# 57                 Al Jadidah    1.000000     1.000000
# 507                      oman    1.000000     1.000000
# 56               Al Humriyyah    1.000000     1.000000
# 399      Sahnwt Al Janubiyyah    1.029677     1.000000
# 131                  Al-Kamil    1.050000     1.000000
# 441                     Tarif    1.052632     1.000000
# 311  Maabilah Industrial Area    1.075758     1.000000
# 368                   Qairoon    1.083333     1.000000
# 392                       SUR    1.127907     1.000000
# 331              Mawala South    1.148410     1.000000
# 45                   Al Hafah    1.151786     1.000000
# 164                    Bahela    1.216667     1.000000
# 249                     Hasik    1.222222     1.000000
# 512              salalah city    1.231320     1.000000
# 15                  AL wistha    1.232558     1.000000
# 495                    khoudh    1.234043     1.000000
# 147                   Amarat     1.238274     1.000000
# 467               Wadid Hatat    1.250000     1.000000
# 396                 Sahalnoot    1.254561     1.000000
# 239                  Ghubrah     1.267327     1.000000
# 153                   As Seeb    1.285714     1.000000
# 126                   Al seeb    1.285714     1.000000
# 465                Wadi Kabir    1.307564     1.000000
# 198                    DOFHAR    1.309091     1.000000
# 53                 Al Hasilah    1.309568     1.000000
# 104                   Al Safa    1.333333     1.000000
# 79                  Al Kuwair    1.355932     1.000000
# 16                     AMERAT    1.361111     1.000000
# 473               al khaburah    1.370370     1.000000
# 401                  Salalah     1.386415     1.000000
# 72                 Al Kharath    1.395073     1.000000
# 247                   Hamriya    1.400000     1.000000
# 522                wadi kabir    1.409091     1.000000
# 355               New Salalah    1.410646     1.000000
# 82                Al Maabilah    1.427509     1.000000
# 39                  Al Burami    1.428571     1.000000
# 149                      Amla    1.453782     1.000000
# 137               Al-Mutazzah    1.461538     1.000000
# 326                     Manah    1.463333     1.000000
# 142                  Alghubra    1.500000     1.000000
# 27                   Al Araqi    1.500000     1.000000
# 436                   TARMAD     1.500000     1.000000
# 98                 Al Musanna    1.560000     1.000000
# 503                  musannah    1.560484     1.000000
# 254                      IBRA    1.582255     1.000000
# 379                   Raysut     1.583333     1.000000
# 214                    Dofhar    1.593750     1.000000
# 480                     aziba    1.597122     1.000000
# 365                   Phase 2    1.600000     1.000000
# 75                  Al Khawd     1.625000     1.000000
# 350                     NIZWA    1.633039     1.000000
# 203                   Darsait    1.648936     1.000000
# 425            South Batinah     1.680000     1.000000
# 362           North Batinah      1.680000     1.000000
# 435                     TAQAH    1.692308     1.000000
# 364                      Oman    1.700000     1.000000
# 157                     Awqad    1.706999     1.000000
# 206                    Deerez    1.708333     1.000000
# 482                    baraka    1.712418     1.000000
# 135               Al-Musanna     1.714286     1.000000
# 42                  Al Ghubra    1.733333     1.000000
# 10                  AL KHUWIR    1.734694     1.000000
# 466                  Wadi Say    1.743590     1.000000
# 31                   Al Awabi    1.761905     1.000000
# 148                    Amerat    1.773639     1.000000
# 120                    Al eeb    1.785714     1.000000
# 77                  Al Khoudh    1.786364     1.000000
# 437                   THARMAD    1.800000     1.000000
# 308                 Ma Mutah     1.808219     1.000000
# 108                Al Sharadi    1.821429     1.000000
# 154               As Subaykhi    1.828025     1.000000
# 160                    Azaiba    1.848168     1.000000
# 407             Samad AlShan     1.857143     1.000000
# 258           Ibra Al Mudaibi    1.891892     1.000000
# 0                 Al Maabilah    1.916667     1.000000
# 89                 Al Mawaleh    1.921739     1.000000
# 55                    Al Hayl    1.922156     1.000000
# 74                   Al Khawd    1.923077     1.000000
# 289                   Khabura    1.932836     1.000000
# 21                  Al Amarat    1.962559     1.000000
# 369    Qasabiyat az Zau0027ab    1.964286     1.000000
# 329                    Matrah    1.990826     1.000000
# 141                 Alburaimi    1.997214     1.000000
# 28                Al Ashkhara    2.000000     1.000000
# 461              Wadi Bahayis    2.000000     1.000000
# 226            Falaj al Qabil    2.000000     1.000000
# 391        SOUTH Al Dakliya      2.000000     1.000000
# 112          Al Wadi Al Kabir    2.000000     1.000000
# 511                   salalah    2.005707     1.000000
# 24                   Al Amrat    2.011111     1.000000
# 515                    shinas    2.017857     1.000000
# 130                   Al-Hail    2.030769     1.000000
# 491                  khaboora    2.036585     1.000000
# 207                 Dhahirah     2.051282     1.000000
# 259                      Ibri    2.055198     1.000000
# 146                    Amarat    2.062168     1.000000
# 300                    Lizugh    2.075949     1.000000
# 43                 Al Ghubrah    2.077922     1.000000
# 301                   MABELAH    2.097561     1.000000
# 375                     Qurum    2.108553     1.000000
# 452                     Ukdha    2.109091     1.000000
# 352                     Nakhl    2.120000     1.000000
# 479                     awqad    2.125000     1.000000
# 69                 Al Khabura    2.126471     1.000000
# 372                  Qurayyat    2.126984     1.000000
# 389                     SOHAR    2.144231     1.000000
# 302                   MAWALIH    2.160000     1.000000
# 455                 Wadi Adai    2.166667     1.000000
# 152                 As Sabkha    2.166667     1.000000
# 41                 Al Buraymi    2.173913     1.000000
# 235                     Ghala    2.180988     1.000000
# 345                   Muscat     2.184721     1.000000
# 46                    Al Hail    2.204715     1.000000
# 223                     Falaj    2.208333     1.000000
# 469                    Yanqul    2.210256     1.000000
# 384                      Ruwi    2.243012     1.000000
# 140                   AlEdybh    2.244444     1.000000
# 83               Al Maabilah     2.254386     1.000000
# 386                   SALALAH    2.255061     1.000000
# 176                   Bawshar    2.298208     1.000000
# 195                   Buraimi    2.302396     1.000000
# 122                  Al khoud    2.302632     1.000000
# 129         Al-Ghubrah South     2.310345     1.000000
# 84                 Al Mabilah    2.311765     1.000000
# 312                    Mabela    2.316567     1.000000
# 400                   Salalah    2.321842     1.032360
# 265               JALAN BUALI    2.326923     1.000000
# 105                   Al Seeb    2.331924     1.000000
# 332                    Mirbat    2.338095     1.000000
# 504                    muscat    2.344687     1.000000
# 178                   Bawsher    2.350000     1.000000
# 361             North Batinah    2.363636     1.000000
# 60                   Al Jazih    2.375000     1.000000
# 305                    MUSCUT    2.400000     1.000000
# 408                    Samail    2.408249     1.000000
# 26                    Al Aqar    2.420000     1.000000
# 506                     nizwa    2.421231     1.000000
# 49              Al Hail South    2.428571     1.000000
# 107        Al Seeb Al Jadidah    2.432432     1.000000
# 381                    Rumais    2.433333     1.000000
# 34                Al Bathinha    2.484848     1.000000
# 73                   Al Khaud    2.496503     1.000000
# 144                    Alnsab    2.500000     1.000000
# 427                  Subaikhi    2.500000     1.000000
# 155               As Sunaynah    2.500000     1.000000
# 167                     Barka    2.511277     1.001064
# 303                   MUSANNA    2.520000     1.000000
# 106                  Al Seeb     2.528125     1.000000
# 196                   Buraymi    2.529412     1.000000
# 78                 Al Khuwair    2.531832     1.000000
# 463           Wadi Bin Khalid    2.545455     1.000000
# 188                     Billa    2.546875     1.000000
# 446                   Thermad    2.548077     1.000000
# 481                    bahlah    2.562500     1.000000
# 319            Madina tul Haq    2.568528     1.000000
# 353                     Naman    2.571429     1.000000
# 317                   Mabilah    2.587500     1.000000
# 2                           0    2.587598     1.000000
# 90           Al Mawaleh South    2.600000     1.000000
# 460         Wadi Baani Khalid    2.604167     1.000000
# 51                   Al Hamra    2.611570     1.000000
# 123                Al khuwair    2.613636     1.000000
# 464                Wadi Hatat    2.619565     1.000000
# 177                 Bawshar      2.620690     1.000000
# 521            wadi al kabeer    2.625000     1.000000
# 264                      Izki    2.643198     1.000000
# 434                    Suwayq    2.659763     1.000000
# 81                Al Kwurriat    2.666667     1.000000
# 373                   Quriyat    2.684625     1.000000
# 409                  Sanaiyah    2.709677     1.000000
# 287                  Khaboora    2.716854     1.000000
# 93                 Al Mudaybi    2.717742     1.000000
# 468                    YANQUL    2.718750     1.000000
# 117                   Al aqar    2.724138     1.000000
# 110                 Al Suwaiq    2.726283     1.000000
# 44                    Al Hafa    2.735294     1.000000
# 397                     Saham    2.737999     1.000000
# 139                Al-batinha    2.742081     1.000000
# 351                    Nakhal    2.743562     1.000000
# 358                    Nizwa     2.752156     1.000000
# 286         Khabbat Al Khamis    2.754717     1.000000
# 22                  Al Amerat    2.756757     1.000000
# 271        Jalaan Bani Bu Ali    2.757764     1.000000
# 456                  Wadi Adi    2.763158     1.000000
# 347                    Mutrah    2.771429     1.000000
# 266                   JUFNAYN    2.773585     1.000000
# 175                   Baushar    2.777778     1.000000
# 462          Wadi Bani Khalid    2.777778     1.000000
# 244                    Halban    2.780000     1.000000
# 96              Al Mukhamarah    2.783784     1.000000
# 457                 Wadi Adi     2.789474     1.000000
# 398                   Sahnawt    2.789474     1.000000
# 382                    Rustaq    2.798339     1.000000
# 277         Jalan Bani Buali     2.800000     1.000000
# 444              Tawi Kuraysh    2.800000     1.000000
# 18                       Adam    2.811373     1.000000
# 25                   Al Ansab    2.826087     1.000000
# 430                       Sur    2.831247     1.000000
# 255                      IBRI    2.841798     1.000000
# 76                   Al Khoud    2.849811     1.000000
# 346                   Mussana    2.857143     1.000000
# 166                    Bahla     2.862595     1.000000
# 275      Jalan Bani Bu Hassan    2.877246     1.000000
# 138                 Al-Rustaq    2.882353     1.000000
# 315                  Mabellah    2.899083     1.000000
# 304                    MUSCAT    2.939024     1.000000
# 48              Al Hail North    2.940000     1.000000
# 67                Al Khaboura    2.940467     1.000000
# 410                  Sanayyah    2.948148     1.000000
# 406             Samad Al Shan    2.958333     1.000000
# 439                     Tanuf    2.961538     1.000000
# 376                      RUWI    3.000000     1.000000
# 288                  Khaboura    3.000000     1.000000
# 523                wadikabeer    3.000000     1.000000
# 182                    Bidaya    3.000000     1.000000
# 85                    Al Mahj    3.000000     1.000000
# 292           Khadrah Al Seah    3.019231     1.000000
# 47                   Al Hail     3.022222     1.000000
# 128                   Al-Duqm    3.023810     1.000000
# 227                     Fanja    3.029289     1.000000
# 150                 Ar Rumays    3.047059     1.000000
# 161                   Azaiba     3.069149     1.000000
# 421                    Sohar     3.074627     1.000000
# 250                     Hayma    3.074766     1.000000
# 424         South Al Mabilah     3.088889     1.000000
# 485                      duqm    3.100000     1.000000
# 215                    Dohfar    3.103448     1.000000
# 505                  mussanah    3.105960     1.000000
# 486                     fanja    3.107143     1.000000
# 230                     GHALA    3.117647     1.000000
# 257                      Ibra    3.120462     1.000000
# 237                    Ghubra    3.130407     1.000000
# 70                Al Khaburah    3.150000     1.000000
# 156                 As Suwayq    3.154545     1.000000
# 454               WADI KABEER    3.166667     1.000000
# 474                 al khuwir    3.166667     1.000000
# 290                    Khadra    3.179348     1.000000
# 165                     Bahla    3.181562     1.000000
# 99                Al Musannah    3.192278     1.000000
# 213                     Diyan    3.223140     1.000000
# 4                  AD Dahirah    3.233333     1.000000
# 3                  AD DAHIRAH    3.240741     1.000000
# 342                   Musanna    3.245000     1.000000
# 1                    Mawaleh     3.246575     1.000000
# 261                     Iizug    3.250000     1.000000
# 209                     Dhank    3.251397     1.000000
# 343                  Musannah    3.272915     1.000000
# 453                     Uqdah    3.285714     1.000000
# 101                   Al Qala    3.285714     1.000000
# 433                    Suwaiq    3.300000     1.000000
# 262                     Ijari    3.302521     1.000000
# 219            Dyan Al Jahwar    3.308511     1.000000
# 412                    Sawadi    3.315789     1.000000
# 429                  Sumharam    3.357143     1.000000
# 357                     Nizwa    3.357514     1.042758
# 418                   Shinas     3.372751     1.000000
# 168                    Barka     3.382353     1.000000
# 513                   sanayya    3.387097     1.000000
# 320            Madinat Al Haq    3.400000     1.000000
# 23                  Al Amirat    3.400000     1.000000
# 95                Al Mudhaibi    3.400330     1.000000
# 201                    Dalqut    3.458333     1.000000
# 443           Tawi Bedi Guish    3.459057     1.000000
# 210                    Dhofar    3.461538     1.000000
# 111                 Al Suwayq    3.462963     1.000000
# 387                    SHINAS    3.464396     1.000000
# 212          Dima Wattayeen      3.464646     1.000000
# 313                   Mabela     3.470588     1.000000
# 125                Al musanna    3.475728     1.000000
# 470                      Yiti    3.476190     1.000000
# 9                     AL Hayl    3.488889     1.000000
# 445                   Tharmad    3.498599     1.000000
# 200                    Dalkut    3.500000     1.000000
# 171                   Bathina    3.500000     1.000000
# 194                     Bukha    3.500000     1.000000
# 54                   Al Hayin    3.500000     1.000000
# 17                  Abu Abali    3.514493     1.000000
# 50                  Al Hambar    3.546875     1.000000
# 145                  Alsuwayq    3.548780     1.000000
# 333                     Misfa    3.571429     1.000000
# 516                     sinaw    3.578857     1.000000
# 88                 Al Masnaah    3.583333     1.000000
# 143                   Alhmbar    3.600000     1.000000
# 59                   Al Jazer    3.615385     1.000000
# 508                     qurum    3.615385     1.000000
# 173                   Batinah    3.617274     1.000000
# 114                 Al Wistha    3.620690     1.000000
# 251                     Hijar    3.640000     1.000000
# 151                Ar Rumays     3.651515     1.000000
# 339                  Murayjat    3.654762     1.000000
# 330                   Mattrah    3.656716     1.000000
# 220              East Salalah    3.666667     1.000000
# 299                     Liwa     3.687500     1.000000
# 174                  Battinah    3.700000     1.000000
# 197        Buraymi/Khadra Seh    3.700000     1.000000
# 404                   Sallaha    3.705882     1.000000
# 383                   Rustaq     3.727273     1.000000
# 132      Al-Kamil and Al-Wafi    3.738095     1.000000
# 366              QARN AL ALAM    3.750000     1.000000
# 282      Jalan bani bu hassan    3.760383     1.000000
# 189                   Bousher    3.762846     1.000000
# 293                    Khasab    3.766298     1.000000
# 61                  Al Jifnan    3.777778     1.000000
# 428                     Suhar    3.778373     1.000000
# 222                     Fahud    3.781250     1.000000
# 509                      ruwi    3.809783     1.000000
# 253                Hujayrimat    3.813953     1.000000
# 514                      seeb    3.875000     1.000000
# 394                   SUWAIQ     3.878788     1.000000
# 284            Jalan bu hasan    3.898305     1.000000
# 162                     BARKA    3.928571     1.000000
# 499                    mawala    3.942857     1.000000
# 187                     Bidya    3.974149     1.000000
# 420                     Sohar    3.974208     1.000000
# 298                      Liwa    3.974751     1.000000
# 268     Jaalan Bani Bu Hassan    3.980501     1.000000
# 377              Ras Madrakah    4.000000     1.000000
# 380                    Razat     4.000000     1.000000
# 124                Al maladah    4.000000     1.000000
# 370                    Qaysad    4.000000     1.000000
# 228                     Filim    4.000000     1.000000
# 390         SOUTH Al Dakliya     4.000000     1.000000
# 334                    Misfah    4.000000     1.000000
# 422          South Al Dakliya    4.000000     1.000000
# 487                     ghala    4.000000     1.000000
# 113                   Al Wafi    4.006154     1.000000
# 71               Al Khaburah     4.020000     1.000000
# 374                  Qurrayat    4.024590     1.000000
# 218                     Duqum    4.048548     1.000000
# 278       Jalan Bani Buhassan    4.085890     1.000000
# 234                  Ghafteen    4.095238     1.000000
# 438                     Tanam    4.096774     1.000000
# 121               Al khaburah    4.114286     1.000000
# 432               Sur Bugrain    4.116279     1.000000
# 30              Al Ashkharah     4.123853     1.000000
# 8                   AL BUSTAN    4.125000     1.000000
# 246            Hamra Al Drooa    4.136364     1.000000
# 283              Jalan bu ali    4.142222     1.000000
# 294                   Khasab     4.150000     1.000000
# 92               Al Mazyunah     4.201587     1.000000
# 458            Wadi Al Maawil    4.214286     1.000000
# 232                   Ghadfan    4.220339     1.000000
# 417                    Shinas    4.226558     1.000000
# 91                Al Mazyunah    4.230241     1.000000
# 181                   Bid Bid    4.292308     1.000000
# 354             Naseem Garden    4.300000     1.000000
# 19                 Adh Dhahir    4.301887     1.000000
# 38                 Al Buraimi    4.302937     1.000000
# 185                    Bidiya    4.309951     1.000000
# 322                    Mahoot    4.318182     1.000000
# 40                 Al Burami     4.333333     1.000000
# 281         Jalan bani bu ali    4.349442     1.000000
# 411                   Sarfayt    4.350000     1.000000
# 274         Jalan Bani Bu Ali    4.380898     1.000000
# 58                   Al Jazar    4.448000     1.000000
# 14                 AL buraimi    4.500000     1.000000
# 133                Al-Khabura    4.500000     1.000000
# 267        Jaalan Bani Bu Ali    4.515723     1.000000
# 359        North Al Dakhliya     4.516129     1.000000
# 335                    Mitali    4.552795     1.000000
# 102                 Al Rumais    4.562500     1.000000
# 64        Al Kamil Wa Al Wadi    4.566667     1.000000
# 116                 Al Zahira    4.574713     1.000000
# 184                   Bidayah    4.606936     1.000000
# 245                    Hamasa    4.615385     1.000000
# 349                   Muttrah    4.617117     1.000000
# 169     Barka Industrial Area    4.629032     1.000000
# 225              Falaj Qabail    4.633333     1.000000
# 269              Jaalan Buali    4.636364     1.000000
# 336                    Mohout    4.637931     1.000000
# 97                Al Musanaah    4.642857     1.000000
# 279              Jalan Bu Ali    4.644467     1.000000
# 29               Al Ashkharah    4.651515     1.000000
# 451                      Tiwi    4.656250     1.000000
# 405            Sallaha Rumais    4.666667     1.000000
# 388                     SINAW    4.673469     1.000000
# 272                     Jalan    4.681015     1.000000
# 510                     saham    4.700000     1.000000
# 172                  Bathina     4.714286     1.000000
# 431             Sur Al Mazari    4.727273     1.000000
# 493                khadra new    4.732143     1.000000
# 471                al batinah    4.733333     1.000000
# 217                     Duqm     4.750000     1.000000
# 192                  Bu Hasan    4.794737     1.000000
# 371               Qiron Herti    4.794872     1.000000
# 241                      HAIL    4.800000     1.000000
# 273            Jalan  bu Ali     4.805016     1.000000
# 341                  Musandam    4.830698     1.000000
# 62                   Al Kamil    4.847127     1.000000
# 363              North Dhariz    4.868421     1.000000
# 238                   Ghubrah    4.882353     1.000000
# 216                      Duqm    4.882838     1.000000
# 490         jalan bani bu ali    4.884391     1.000000
# 348                   Mutrah     4.909091     1.000000
# 243                     Haima    4.909091     1.000000
# 5                  AD Dahirha    4.916667     1.000000
# 33   Al Azaiba heights street    4.937500     1.000000
# 496                      liwa    4.941176     1.000000
# 109                 Al Suwaih    4.956522     1.000000
# 163                   BATINAH    4.963636     1.000000
# 328                   Masirah    4.970110     1.007984
# 52                 Al Hamriya    5.000000     1.000000
# 498                   masirah    5.010204     1.000000
# 414             Shahab Ase'eb    5.074074     1.000000
# 321                    Mahdah    5.082759     1.000000
# 276          Jalan Bani Buali    5.087938     1.000000
# 256                      IZKI    5.116883     1.000000
# 94                  Al Mudayq    5.166667     1.000000
# 86                  Al Mahoot    5.181818     1.000000
# 338                  Muladdah    5.196078     1.000000
# 20                   Al Aflaj    5.266667     1.000000
# 296                     LIWA     5.329609     1.000000
# 450                   Thumryt    5.333333     1.000000
# 494                    khasab    5.425532     1.000000
# 318                     Madha    5.455090     1.000000
# 119               Al buraimi     5.487179     1.000000
# 447                  Thumrait    5.533311     1.000000
# 248                    Harmul    5.536232     1.000000
# 193                  Bu hasan    5.550725     1.000000
# 415                    Shalim    5.560209     1.000000
# 291      Khadra AL Bu Rishayd    5.647059     1.000000
# 11                 AL Khuwair    5.777778     1.000000
# 295                      LIWA    5.849206     1.000000
# 327                    Marmul    5.855346     1.000000
# 325                     Majan    5.977778     1.000000
# 127                   Al-Biya    6.000000     1.000000
# 488                      ibra    6.000000     1.000000
# 190                  Bousher     6.000000     1.000000
# 472                al hoqain     6.000000     1.000000
# 136               Al-Musannah    6.015625     1.000000
# 12               AL SHARQIYAH    6.111111     1.000000
# 191                   Bowsher    6.150000     1.000000
# 367           Qaimah Ashkhara    6.153846     1.000000
# 419                     Sinaw    6.177093     1.000000
# 263   Industrail Area Buraimi    6.250000     1.000000
# 37                Al Bidayah     6.285714     1.000000
# 489                      ibri    6.400000     1.000000
# 208                   Dhalkut    6.400000     1.000000
# 393                    SUWAIQ    6.496063     1.000000
# 449                  Thumrayt    6.500000     1.000000
# 416                     Sheer    6.500000     1.000000
# 118                Al batinah    6.518072     1.000000
# 310                  Maabilah    6.545455     1.000000
# 459             Wadi Al Mawil    6.785714     1.000000
# 337             Mudaybi/Sinaw    6.795539     1.000000
# 65        Al Kamil Wa Al Wafi    6.833333     1.000000
# 233                  Ghadfan     6.843750     1.000000
# 395                     Sadah    6.965517     1.000000
# 252                      Hijj    6.979592     1.000000
# 324                    Mahout    7.022556     1.000000
# 87                Al Makhasfa    7.132075     1.000000
# 448                 Thumrait     7.404762     1.000000
# 199              Daba Al biya    7.666667     1.000000
# 63                  Al Kamil     7.692308     1.000000
# 202                     Dariz    7.764706     1.000000
# 356                      Nimr    7.870968     1.000000
# 378                    Raysut    8.000000     1.000000
# 32                  Al Awabi     8.000000     1.000000
# 240                     Gobra    8.000000     1.000000
# 307                   MUTTRAH    8.166667     1.000000
# 483                     barka    8.187500     1.000000
# 100                  Al Qabil    8.285714     1.000000
# 158                Az Zahirah    8.411765     1.000000
# 323                   Mahoot     9.333333     1.000000
# 500                       mct   10.000000     1.000000
# 501                   mudhibi   10.000000     1.000000
# 229                      Fins   10.222222     1.000000
# 205            Deema W Tayeen   10.666667     1.000000
# 476                   alansab   12.000000     1.000000
# 134                Al-Khuwair   12.111111     1.000000
# 442                Tawi Atair   24.000000     1.000000
# 297                    Lakabi   27.973684     1.000000
# 440                     Taqah   30.915929     1.000000
# 517                     sohar   34.380432     2.493525
# 344                    Muscat   45.546950     9.345000
# 413                      Seeb   45.631259     1.160037
# 236                   Ghoubra   77.967033     1.000000
# 7                  AL BATINHA  337.666667     1.000000
# 478       ash sharqiyah south  344.563636    26.257576
# 316                    Mabila  490.451818     1.000000
# 475                   al seeb  573.954545    68.954545
